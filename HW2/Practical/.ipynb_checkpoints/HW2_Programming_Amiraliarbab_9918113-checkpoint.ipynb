# %% [markdown]
# # Question 1

# %%
# import libararies
import pandas as pd 
import numpy as np
import sklearn
import matplotlib.pyplot as plt

# %%
path = "./data/car_data.csv"
df = pd.read_csv(path)

# %% [markdown]
# ## Visualize Data

# %%
# show first 5 row
df.head()
# Out:
#    User ID Gender  Age  AnnualSalary  Purchased
# 0      385   Male   35         20000          0
# 1      681   Male   40         43500          0
# 2      353   Male   49         74000          0
# 3      895   Male   40        107500          1
# 4      661   Male   25         79000          0

# %%
# histogram for Age column
df.Age.plot(kind="hist")
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
# pie chart for Gender column
df.Gender.value_counts().plot(kind="pie");

# %% [markdown]
# ## Preprocessing

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   User ID       1000 non-null   int64
#  1   Gender        1000 non-null   object
#  2   Age           1000 non-null   int64
#  3   AnnualSalary  1000 non-null   int64
#  4   Purchased     1000 non-null   int64
# dtypes: int64(4), object(1)
# memory usage: 39.2+ KB

# %%
# Turn the Gender column to numerical values 
df = pd.concat([df.drop(columns="Gender") , pd.get_dummies(df["Gender"] ,prefix="Gender" , prefix_sep="_")] , axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   User ID        1000 non-null   int64
#  1   Age            1000 non-null   int64
#  2   AnnualSalary   1000 non-null   int64
#  3   Purchased      1000 non-null   int64
#  4   Gender_Female  1000 non-null   uint8
#  5   Gender_Male    1000 non-null   uint8
# dtypes: int64(4), uint8(2)
# memory usage: 33.3 KB

# %%
df.head(100)
# Out:
#     User ID  Age  AnnualSalary  Purchased  Gender_Female  Gender_Male
# 0       385   35         20000          0              0            1
# 1       681   40         43500          0              0            1
# 2       353   49         74000          0              0            1
# 3       895   40        107500          1              0            1
# 4       661   25         79000          0              0            1
# ..      ...  ...           ...        ...            ...          ...
# 95      485   33        151500          1              1            0
# 96      960   45         75500          1              0            1
# 97      233   26         17000          0              1            0
# 98      191   30         87000          0              0            1
# 99      471   38         60500          0              0            1
#
# [100 rows x 6 columns]

# %% [markdown]
# ## Drop User ID

# %%
df = df.drop(columns=["User ID"])

# %% [markdown]
# ### Split Data

# %% [markdown]
# For preventing `Data Leakage` we first should split data into `train` & `test` sets then apply `fit`on train and then apply `Transform` on `train` and `test` sets .

# %%
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(df.drop(columns=["Purchased"]),df.Purchased , test_size=0.2  , random_state=42)
x_train.shape , x_test.shape , y_train.shape , y_test.shape
# Out:
# ((800, 4), (200, 4), (800,), (200,))

# %%
x_train
# Out:
#      Age  AnnualSalary  Gender_Female  Gender_Male
# 29    38        147500              1            0
# 535   59         24500              1            0
# 695   35         91000              0            1
# 557   43         76500              1            0
# 836   31        118000              1            0
# ..   ...           ...            ...          ...
# 106   36         56500              0            1
# 270   42         53000              1            0
# 860   37         33000              1            0
# 435   43        112000              1            0
# 102   26         80000              0            1
#
# [800 rows x 4 columns]

# %%
# Scale the features
from sklearn.preprocessing import StandardScaler
std_x = StandardScaler()
# Fit the scaler
x_train_norm = pd.DataFrame(std_x.fit_transform(x_train),columns=x_train.columns)
x_test_norm = pd.DataFrame(std_x.transform(x_test),columns=x_test.columns)
x_train_norm.shape , x_test_norm.shape
# Out:
# ((800, 4), (200, 4))

# %%
x_train_norm
# Out:
#           Age  AnnualSalary  Gender_Female  Gender_Male
# 0   -0.180280      2.152137       0.965592    -0.965592
# 1    1.782584     -1.407626       0.965592    -0.965592
# 2   -0.460689      0.516961      -1.035635     1.035635
# 3    0.287069      0.097315       0.965592    -0.965592
# 4   -0.834568      1.298373       0.965592    -0.965592
# ..        ...           ...            ...          ...
# 795 -0.367219     -0.481509      -1.035635     1.035635
# 796  0.193599     -0.582803       0.965592    -0.965592
# 797 -0.273749     -1.161626       0.965592    -0.965592
# 798  0.287069      1.124726       0.965592    -0.965592
# 799 -1.301916      0.198609      -1.035635     1.035635
#
# [800 rows x 4 columns]

# %%
x_train_norm = x_train_norm.to_numpy()
x_test_norm = x_test_norm.to_numpy()

# %%
y_train = np.expand_dims(y_train,axis=1)
y_test = np.expand_dims(y_test , axis=1)

# %% [markdown]
# # Logistic Regression

# %%
def sigmoid(x):
    return (1.0/ (1 + np.exp(-x))).astype(np.float128)

# %%
def cross_entropy(y , x , w):
    y_hat = sigmoid(x.dot(w))
    loss = y.T.dot(np.log(y_hat)) + (1-y).T.dot(np.log(1-y_hat))
    return np.squeeze(-loss)

# %%
def gradient_descent(y , x , w , gamma , Train):
    loss = cross_entropy(y , x , w)
    # calculate gradient
    y_hat = sigmoid(x.dot(w))
    if Train:
        gradient = x.T.dot(y_hat - y)
        w = w - (gamma * gradient)
    acc = float(np.equal(y_hat , y).sum() / len(y)) 
    return acc * 100 , loss , w

# %%
Epoch = 100000
# List for track loss and acc in Train dataset
loss_T = []
acc_T = []
# List for track loss and acc in Test dataset
loss_Te = []
acc_Te = []
# List for track weights
w_T = []
# List for trach epochs
epochs = []
# Learing rate & EarlyStop Thershold
gamma = 0.1
thershold = 1e-2
w = np.zeros((5,1))
for i in range(Epoch):
    # Train model
    accT , lossT , w = gradient_descent(y_train , np.c_[np.ones(x_train_norm.shape[0]),x_train_norm] , w ,gamma , Train = True) 
    acc_T.append(accT)
    loss_T.append(lossT)
    w_T.append(w)
    # Test model
    accTe , lossTe , w = gradient_descent(y_test , np.c_[np.ones(x_test_norm.shape[0]) , x_test_norm] , w ,gamma , Train = False) 
    acc_Te.append(accTe)
    loss_Te.append(lossTe)
    epochs.append(i)
    if i % 100 == 0 :
        print(f"Epoch : {i} Train Loss : {lossT:.2f} Train Accuracy : {accT:.2f} Test Loss : {lossTe:.2f} Test Accuracy : {accTe:.2f}")
        
    if len(loss_T) > 1 and np.abs(loss_Te[-1] - loss_Te[-2]) < thershold :
        break
# Out:
# /tmp/ipykernel_3735/3691303277.py:3: RuntimeWarning: divide by zero encountered in log
#   loss = y.T.dot(np.log(y_hat)) + (1-y).T.dot(np.log(1-y_hat))
# Epoch : 0 Train Loss : 554.52 Train Accuracy : 0.00 Test Loss : nan Test Accuracy : 6.50
# Epoch : 100 Train Loss : nan Train Accuracy : 2.25 Test Loss : nan Test Accuracy : 4.00
# Epoch : 200 Train Loss : nan Train Accuracy : 2.00 Test Loss : nan Test Accuracy : 6.00
# Epoch : 300 Train Loss : nan Train Accuracy : 6.50 Test Loss : nan Test Accuracy : 11.00
# Epoch : 400 Train Loss : nan Train Accuracy : 5.25 Test Loss : nan Test Accuracy : 8.00
# Epoch : 500 Train Loss : nan Train Accuracy : 3.12 Test Loss : nan Test Accuracy : 5.50
# Epoch : 600 Train Loss : nan Train Accuracy : 2.00 Test Loss : nan Test Accuracy : 4.00
# Epoch : 700 Train Loss : nan Train Accuracy : 2.25 Test Loss : nan Test Accuracy : 9.50
# Epoch : 800 Train Loss : nan Train Accuracy : 6.62 Test Loss : nan Test Accuracy : 10.00
# Epoch : 900 Train Loss : nan Train Accuracy : 3.75 Test Loss : nan Test Accuracy : 7.00
# Epoch : 1000 Train Loss : nan Train Accuracy : 2.38 Test Loss : nan Test Accuracy : 4.50
# Epoch : 1100 Train Loss : nan Train Accuracy : 2.00 Test Loss : nan Test Accuracy : 5.00
# Epoch : 1200 Train Loss : nan Train Accuracy : 5.88 Test Loss : nan Test Accuracy : 10.50
# Epoch : 1300 Train Loss : nan Train Accuracy : 5.62 Test Loss : nan Test Accuracy : 8.00
# Epoch : 1400 Train Loss : nan Train Accuracy : 3.50 Test Loss : nan Test Accuracy : 6.00
# Epoch : 1500 Train Loss : nan Train Accuracy : 2.00 Test Loss : nan Test Accuracy : 3.50
# Epoch : 1600 Train Loss : nan Train Accuracy : 2.12 Test Loss : nan Test Accuracy : 9.00
# Epoch : 1700 Train Loss : nan Train Accuracy : 6.62 Test Loss : nan Test Accuracy : 10.50
# Epoch : 1800 Train Loss : nan Train Accuracy : 4.00 Test Loss : nan Test Accuracy : 7.50
# Epoch : 1900 Train Loss : nan Train Accuracy : 2.88 Test Loss : nan Test Accuracy : 5.50
# Epoch : 2000 Train Loss : nan Train Accuracy : 2.00 Test Loss : nan Test Accuracy : 5.00
# Epoch : 2100 Train Loss : nan Train Accuracy : 5.12 Test Loss : nan Test Accuracy : 10.50
# Epoch : 2200 Train Loss : nan Train Accuracy : 6.12 Test Loss : nan Test Accuracy : 8.50
# Epoch : 2300 Train Loss : nan Train Accuracy : 3.50 Test Loss : nan Test Accuracy : 7.00
# Epoch : 2400 Train Loss : nan Train Accuracy : 2.00 Test Loss : nan Test Accuracy : 4.00
# Epoch : 2500 Train Loss : nan Train Accuracy : 2.12 Test Loss : nan Test Accuracy : 8.50
# Epoch : 2600 Train Loss : nan Train Accuracy : 6.75 Test Loss : nan Test Accuracy : 11.00
# Epoch : 2700 Train Loss : nan Train Accuracy : 4.62 Test Loss : nan Test Accuracy : 7.50
# Epoch : 2800 Train Loss : nan Train Accuracy : 2.88 Test Loss : nan Test Accuracy : 5.50
# Epoch : 2900 Train Loss : nan Train Accuracy : 2.00 Test Loss : nan Test Accuracy : 4.00
# Epoch : 3000 Train Loss : nan Train Accuracy : 3.25 Test Loss : nan Test Accuracy : 10.00
# Epoch : 3100 Train Loss : nan Train Accuracy : 6.38 Test Loss : nan Test Accuracy : 9.00
# Epoch : 3200 Train Loss : nan Train Accuracy : 3.38 Test Loss : nan Test Accuracy : 7.00
# Epoch : 3300 Train Loss : nan Train Accuracy : 2.25 Test Loss : nan Test Accuracy : 4.00
# Epoch : 3400 Train Loss : nan Train Accuracy : 2.00 Test Loss : nan Test Accuracy : 6.50
# Epoch : 3500 Train Loss : nan Train Accuracy : 6.62 Test Loss : nan Test Accuracy : 11.00
# Epoch : 3600 Train Loss : nan Train Accuracy : 5.00 Test Loss : nan Test Accuracy : 8.00
# Epoch : 3700 Train Loss : nan Train Accuracy : 3.12 Test Loss : nan Test Accuracy : 5.50
# Epoch : 3800 Train Loss : nan Train Accuracy : 2.00 Test Loss : nan Test Accuracy : 4.00
# Epoch : 3900 Train Loss : nan Train Accuracy : 2.25 Test Loss : nan Test Accuracy : 9.50
# Epoch : 4000 Train Loss : nan Train Accuracy : 6.62 Test Loss : nan Test Accuracy : 9.00
# Epoch : 4100 Train Loss : nan Train Accuracy : 3.75 Test Loss : nan Test Accuracy : 7.00
# Epoch : 4200 Train Loss : nan Train Accuracy : 2.38 Test Loss : nan Test Accuracy : 4.50
# Epoch : 4300 Train Loss : nan Train Accuracy : 2.00 Test Loss : nan Test Accuracy : 5.00
# Epoch : 4400 Train Loss : nan Train Accuracy : 6.12 Test Loss : nan Test Accuracy : 10.50
# Epoch : 4500 Train Loss : nan Train Accuracy : 5.25 Test Loss : nan Test Accuracy : 8.00
# Epoch : 4600 Train Loss : nan Train Accuracy : 3.50 Test Loss : nan Test Accuracy : 6.00
# Epoch : 4700 Train Loss : nan Train Accuracy : 2.00 Test Loss : nan Test Accuracy : 3.50
# Epoch : 4800 Train Loss : nan Train Accuracy : 2.12 Test Loss : nan Test Accuracy : 9.00
# Epoch : 4900 Train Loss : nan Train Accuracy : 6.62 Test Loss : nan Test Accuracy : 10.50
# Epoch : 5000 Train Loss : nan Train Accuracy : 4.00 Test Loss : nan Test Accuracy : 7.50
# Epoch : 5100 Train Loss : nan Train Accuracy : 2.88 Test Loss : nan Test Accuracy : 5.50
# Epoch : 5200 Train Loss : nan Train Accuracy : 2.00 Test Loss : nan Test Accuracy : 5.00
# Epoch : 5300 Train Loss : nan Train Accuracy : 5.25 Test Loss : nan Test Accuracy : 10.50
# Epoch : 5400 Train Loss : nan Train Accuracy : 6.25 Test Loss : nan Test Accuracy : 8.50
# Epoch : 5500 Train Loss : nan Train Accuracy : 3.50 Test Loss : nan Test Accuracy : 6.50
# Epoch : 5600 Train Loss : nan Train Accuracy : 2.00 Test Loss : nan Test Accuracy : 3.50
# Epoch : 5700 Train Loss : nan Train Accuracy : 2.12 Test Loss : nan Test Accuracy : 9.00
# Epoch : 5800 Train Loss : nan Train Accuracy : 6.75 Test Loss : nan Test Accuracy : 11.00
# Epoch : 5900 Train Loss : nan Train Accuracy : 4.38 Test Loss : nan Test Accuracy : 7.50
# Epoch : 6000 Train Loss : nan Train Accuracy : 2.88 Test Loss : nan Test Accuracy : 5.50
# Epoch : 6100 Train Loss : nan Train Accuracy : 2.00 Test Loss : nan Test Accuracy : 4.50
# Epoch : 6200 Train Loss : nan Train Accuracy : 3.38 Test Loss : nan Test Accuracy : 10.50
# Epoch : 6300 Train Loss : nan Train Accuracy : 6.38 Test Loss : nan Test Accuracy : 9.00
# Epoch : 6400 Train Loss : nan Train Accuracy : 3.38 Test Loss : nan Test Accuracy : 7.00
# Epoch : 6500 Train Loss : nan Train Accuracy : 2.25 Test Loss : nan Test Accuracy : 4.00
# Epoch : 6600 Train Loss : nan Train Accuracy : 2.00 Test Loss : nan Test Accuracy : 6.50
# Epoch : 6700 Train Loss : nan Train Accuracy : 6.62 Test Loss : nan Test Accuracy : 11.50
# Epoch : 6800 Train Loss : nan Train Accuracy : 4.88 Test Loss : nan Test Accuracy : 8.00
# Epoch : 6900 Train Loss : nan Train Accuracy : 3.12 Test Loss : nan Test Accuracy : 5.50
# Epoch : 7000 Train Loss : nan Train Accuracy : 2.00 Test Loss : nan Test Accuracy : 4.00
# Epoch : 7100 Train Loss : nan Train Accuracy : 2.38 Test Loss : nan Test Accuracy : 9.50
# Epoch : 7200 Train Loss : nan Train Accuracy : 6.62 Test Loss : nan Test Accuracy : 9.50
# Epoch : 7300 Train Loss : nan Train Accuracy : 3.75 Test Loss : nan Test Accuracy : 7.00
# Epoch : 7400 Train Loss : nan Train Accuracy : 2.38 Test Loss : nan Test Accuracy : 4.50
# Epoch : 7500 Train Loss : nan Train Accuracy : 2.00 Test Loss : nan Test Accuracy : 5.50
# Epoch : 7600 Train Loss : nan Train Accuracy : 6.25 Test Loss : nan Test Accuracy : 10.50
# Epoch : 7700 Train Loss : nan Train Accuracy : 5.38 Test Loss : nan Test Accuracy : 8.00
# Epoch : 7800 Train Loss : nan Train Accuracy : 3.50 Test Loss : nan Test Accuracy : 6.00
# Epoch : 7900 Train Loss : nan Train Accuracy : 2.00 Test Loss : nan Test Accuracy : 3.50
# Epoch : 8000 Train Loss : nan Train Accuracy : 2.12 Test Loss : nan Test Accuracy : 9.50
# Epoch : 8100 Train Loss : nan Train Accuracy : 6.62 Test Loss : nan Test Accuracy : 10.00
# Epoch : 8200 Train Loss : nan Train Accuracy : 4.00 Test Loss : nan Test Accuracy : 7.00
# Epoch : 8300 Train Loss : nan Train Accuracy : 2.75 Test Loss : nan Test Accuracy : 5.00
# Epoch : 8400 Train Loss : nan Train Accuracy : 2.00 Test Loss : nan Test Accuracy : 5.00
# Epoch : 8500 Train Loss : nan Train Accuracy : 5.50 Test Loss : nan Test Accuracy : 10.50
# Epoch : 8600 Train Loss : nan Train Accuracy : 6.12 Test Loss : nan Test Accuracy : 8.50
# Epoch : 8700 Train Loss : nan Train Accuracy : 3.50 Test Loss : nan Test Accuracy : 6.50
# Epoch : 8800 Train Loss : nan Train Accuracy : 2.00 Test Loss : nan Test Accuracy : 3.50
# Epoch : 8900 Train Loss : nan Train Accuracy : 2.12 Test Loss : nan Test Accuracy : 9.00
# Epoch : 9000 Train Loss : nan Train Accuracy : 6.75 Test Loss : nan Test Accuracy : 11.00
# Epoch : 9100 Train Loss : nan Train Accuracy : 4.25 Test Loss : nan Test Accuracy : 7.50
# Epoch : 9200 Train Loss : nan Train Accuracy : 2.88 Test Loss : nan Test Accuracy : 5.50
# Epoch : 9300 Train Loss : nan Train Accuracy : 2.00 Test Loss : nan Test Accuracy : 4.50
# Epoch : 9400 Train Loss : nan Train Accuracy : 4.00 Test Loss : nan Test Accuracy : 10.50
# Epoch : 9500 Train Loss : nan Train Accuracy : 6.25 Test Loss : nan Test Accuracy : 9.00
# Epoch : 9600 Train Loss : nan Train Accuracy : 3.38 Test Loss : nan Test Accuracy : 7.00
# Epoch : 9700 Train Loss : nan Train Accuracy : 2.25 Test Loss : nan Test Accuracy : 4.00
# Epoch : 9800 Train Loss : nan Train Accuracy : 2.00 Test Loss : nan Test Accuracy : 7.00
# Epoch : 9900 Train Loss : nan Train Accuracy : 6.62 Test Loss : nan Test Accuracy : 11.50
# Epoch : 10000 Train Loss : nan Train Accuracy : 4.75 Test Loss : nan Test Accuracy : 8.00
# Epoch : 10100 Train Loss : nan Train Accuracy : 3.12 Test Loss : nan Test Accuracy : 5.50
# Epoch : 10200 Train Loss : nan Train Accuracy : 2.00 Test Loss : nan Test Accuracy : 4.00
# Epoch : 10300 Train Loss : nan Train Accuracy : 2.38 Test Loss : nan Test Accuracy : 9.50
# Epoch : 10400 Train Loss : nan Train Accuracy : 6.62 Test Loss : nan Test Accuracy : 9.50
# Epoch : 10500 Train Loss : nan Train Accuracy : 3.75 Test Loss : nan Test Accuracy : 7.00
# Epoch : 10600 Train Loss : nan Train Accuracy : 2.38 Test Loss : nan Test Accuracy : 4.50
# Epoch : 10700 Train Loss : nan Train Accuracy : 2.00 Test Loss : nan Test Accuracy : 6.00
# Epoch : 10800 Train Loss : nan Train Accuracy : 6.25 Test Loss : nan Test Accuracy : 10.50
# Epoch : 10900 Train Loss : nan Train Accuracy : 5.25 Test Loss : nan Test Accuracy : 8.00
# Epoch : 11000 Train Loss : nan Train Accuracy : 3.38 Test Loss : nan Test Accuracy : 5.50
# Epoch : 11100 Train Loss : nan Train Accuracy : 2.00 Test Loss : nan Test Accuracy : 3.50
# Epoch : 11200 Train Loss : nan Train Accuracy : 2.12 Test Loss : nan Test Accuracy : 9.50
# Epoch : 11300 Train Loss : nan Train Accuracy : 6.62 Test Loss : nan Test Accuracy : 10.00
# Epoch : 11400 Train Loss : nan Train Accuracy : 3.75 Test Loss : nan Test Accuracy : 7.00
# Epoch : 11500 Train Loss : nan Train Accuracy : 2.62 Test Loss : nan Test Accuracy : 4.50
# Epoch : 11600 Train Loss : nan Train Accuracy : 2.00 Test Loss : nan Test Accuracy : 5.00
# Epoch : 11700 Train Loss : nan Train Accuracy : 5.62 Test Loss : nan Test Accuracy : 10.50
# Epoch : 11800 Train Loss : nan Train Accuracy : 6.00 Test Loss : nan Test Accuracy : 8.50
# Epoch : 11900 Train Loss : nan Train Accuracy : 3.50 Test Loss : nan Test Accuracy : 6.50
# Epoch : 12000 Train Loss : nan Train Accuracy : 2.00 Test Loss : nan Test Accuracy : 3.50
# Epoch : 12100 Train Loss : nan Train Accuracy : 2.12 Test Loss : nan Test Accuracy : 9.00
# Epoch : 12200 Train Loss : nan Train Accuracy : 6.75 Test Loss : nan Test Accuracy : 11.00
# Epoch : 12300 Train Loss : nan Train Accuracy : 4.12 Test Loss : nan Test Accuracy : 7.50
# Epoch : 12400 Train Loss : nan Train Accuracy : 2.88 Test Loss : nan Test Accuracy : 5.50
# Epoch : 12500 Train Loss : nan Train Accuracy : 2.00 Test Loss : nan Test Accuracy : 4.50
# Epoch : 12600 Train Loss : nan Train Accuracy : 4.25 Test Loss : nan Test Accuracy : 10.50
# Epoch : 12700 Train Loss : nan Train Accuracy : 6.25 Test Loss : nan Test Accuracy : 9.00
# Epoch : 12800 Train Loss : nan Train Accuracy : 3.38 Test Loss : nan Test Accuracy : 7.00
# Epoch : 12900 Train Loss : nan Train Accuracy : 2.00 Test Loss : nan Test Accuracy : 4.00
# Epoch : 13000 Train Loss : nan Train Accuracy : 2.12 Test Loss : nan Test Accuracy : 7.50
# Epoch : 13100 Train Loss : nan Train Accuracy : 6.62 Test Loss : nan Test Accuracy : 11.00
# Epoch : 13200 Train Loss : nan Train Accuracy : 4.62 Test Loss : nan Test Accuracy : 8.00
# Epoch : 13300 Train Loss : nan Train Accuracy : 3.12 Test Loss : nan Test Accuracy : 5.50
# Epoch : 13400 Train Loss : nan Train Accuracy : 2.00 Test Loss : nan Test Accuracy : 4.00
# Epoch : 13500 Train Loss : nan Train Accuracy : 2.62 Test Loss : nan Test Accuracy : 10.00
# Epoch : 13600 Train Loss : nan Train Accuracy : 6.38 Test Loss : nan Test Accuracy : 9.00
# Epoch : 13700 Train Loss : nan Train Accuracy : 3.50 Test Loss : nan Test Accuracy : 7.00
# Epoch : 13800 Train Loss : nan Train Accuracy : 2.38 Test Loss : nan Test Accuracy : 4.00
# Epoch : 13900 Train Loss : nan Train Accuracy : 2.00 Test Loss : nan Test Accuracy : 6.00
# Epoch : 14000 Train Loss : nan Train Accuracy : 6.38 Test Loss : nan Test Accuracy : 10.50
# Epoch : 14100 Train Loss : nan Train Accuracy : 5.25 Test Loss : nan Test Accuracy : 8.00
# Epoch : 14200 Train Loss : nan Train Accuracy : 3.38 Test Loss : nan Test Accuracy : 5.50
# Epoch : 14300 Train Loss : nan Train Accuracy : 2.00 Test Loss : nan Test Accuracy : 3.50
# Epoch : 14400 Train Loss : nan Train Accuracy : 2.12 Test Loss : nan Test Accuracy : 9.50
# Epoch : 14500 Train Loss : nan Train Accuracy : 6.62 Test Loss : nan Test Accuracy : 10.00
# Epoch : 14600 Train Loss : nan Train Accuracy : 3.75 Test Loss : nan Test Accuracy : 7.00
# Epoch : 14700 Train Loss : nan Train Accuracy : 2.62 Test Loss : nan Test Accuracy : 4.50
# Epoch : 14800 Train Loss : nan Train Accuracy : 2.00 Test Loss : nan Test Accuracy : 5.00
# Epoch : 14900 Train Loss : nan Train Accuracy : 5.75 Test Loss : nan Test Accuracy : 10.50
# Epoch : 15000 Train Loss : nan Train Accuracy : 6.00 Test Loss : nan Test Accuracy : 8.50
# Epoch : 15100 Train Loss : nan Train Accuracy : 3.50 Test Loss : nan Test Accuracy : 6.00
# Epoch : 15200 Train Loss : nan Train Accuracy : 2.00 Test Loss : nan Test Accuracy : 3.50
# Epoch : 15300 Train Loss : nan Train Accuracy : 2.12 Test Loss : nan Test Accuracy : 9.00
# Epoch : 15400 Train Loss : nan Train Accuracy : 6.62 Test Loss : nan Test Accuracy : 11.00
# Epoch : 15500 Train Loss : nan Train Accuracy : 4.12 Test Loss : nan Test Accuracy : 7.50
# Epoch : 15600 Train Loss : nan Train Accuracy : 2.88 Test Loss : nan Test Accuracy : 5.50
# Epoch : 15700 Train Loss : nan Train Accuracy : 2.00 Test Loss : nan Test Accuracy : 4.50
# Epoch : 15800 Train Loss : nan Train Accuracy : 4.75 Test Loss : nan Test Accuracy : 10.50
# Epoch : 15900 Train Loss : nan Train Accuracy : 6.12 Test Loss : nan Test Accuracy : 8.50
# Epoch : 16000 Train Loss : nan Train Accuracy : 3.38 Test Loss : nan Test Accuracy : 7.00
# Epoch : 16100 Train Loss : nan Train Accuracy : 2.00 Test Loss : nan Test Accuracy : 4.00
# Epoch : 16200 Train Loss : nan Train Accuracy : 2.12 Test Loss : nan Test Accuracy : 8.00
# Epoch : 16300 Train Loss : nan Train Accuracy : 6.62 Test Loss : nan Test Accuracy : 11.00
# Epoch : 16400 Train Loss : nan Train Accuracy : 4.62 Test Loss : nan Test Accuracy : 7.50
# Epoch : 16500 Train Loss : nan Train Accuracy : 3.12 Test Loss : nan Test Accuracy : 5.50
# Epoch : 16600 Train Loss : nan Train Accuracy : 2.00 Test Loss : nan Test Accuracy : 4.00
# Epoch : 16700 Train Loss : nan Train Accuracy : 3.12 Test Loss : nan Test Accuracy : 10.00
# Epoch : 16800 Train Loss : nan Train Accuracy : 6.38 Test Loss : nan Test Accuracy : 9.00
# Epoch : 16900 Train Loss : nan Train Accuracy : 3.50 Test Loss : nan Test Accuracy : 7.00
# Epoch : 17000 Train Loss : nan Train Accuracy : 2.25 Test Loss : nan Test Accuracy : 4.00
# Epoch : 17100 Train Loss : nan Train Accuracy : 2.00 Test Loss : nan Test Accuracy : 6.00
# Epoch : 17200 Train Loss : nan Train Accuracy : 6.50 Test Loss : nan Test Accuracy : 10.50
# Epoch : 17300 Train Loss : nan Train Accuracy : 5.25 Test Loss : nan Test Accuracy : 8.00
# Epoch : 17400 Train Loss : nan Train Accuracy : 3.12 Test Loss : nan Test Accuracy : 5.50
# Epoch : 17500 Train Loss : nan Train Accuracy : 2.00 Test Loss : nan Test Accuracy : 4.00
# Epoch : 17600 Train Loss : nan Train Accuracy : 2.25 Test Loss : nan Test Accuracy : 9.50
# Epoch : 17700 Train Loss : nan Train Accuracy : 6.62 Test Loss : nan Test Accuracy : 10.00
# Epoch : 17800 Train Loss : nan Train Accuracy : 3.75 Test Loss : nan Test Accuracy : 7.00
# Epoch : 17900 Train Loss : nan Train Accuracy : 2.38 Test Loss : nan Test Accuracy : 4.50
# Epoch : 18000 Train Loss : nan Train Accuracy : 2.00 Test Loss : nan Test Accuracy : 5.00
# Epoch : 18100 Train Loss : nan Train Accuracy : 5.88 Test Loss : nan Test Accuracy : 10.50
# Epoch : 18200 Train Loss : nan Train Accuracy : 5.75 Test Loss : nan Test Accuracy : 8.00
# Epoch : 18300 Train Loss : nan Train Accuracy : 3.50 Test Loss : nan Test Accuracy : 6.00
# Epoch : 18400 Train Loss : nan Train Accuracy : 2.00 Test Loss : nan Test Accuracy : 3.50
# Epoch : 18500 Train Loss : nan Train Accuracy : 2.12 Test Loss : nan Test Accuracy : 9.00
# Epoch : 18600 Train Loss : nan Train Accuracy : 6.62 Test Loss : nan Test Accuracy : 10.50
# Epoch : 18700 Train Loss : nan Train Accuracy : 4.00 Test Loss : nan Test Accuracy : 7.50
# Epoch : 18800 Train Loss : nan Train Accuracy : 2.88 Test Loss : nan Test Accuracy : 5.50
# Epoch : 18900 Train Loss : nan Train Accuracy : 2.00 Test Loss : nan Test Accuracy : 5.00
# Epoch : 19000 Train Loss : nan Train Accuracy : 5.12 Test Loss : nan Test Accuracy : 10.50
# Epoch : 19100 Train Loss : nan Train Accuracy : 6.12 Test Loss : nan Test Accuracy : 8.50
# Epoch : 19200 Train Loss : nan Train Accuracy : 3.50 Test Loss : nan Test Accuracy : 7.00
# Epoch : 19300 Train Loss : nan Train Accuracy : 2.00 Test Loss : nan Test Accuracy : 4.00
# Epoch : 19400 Train Loss : nan Train Accuracy : 2.12 Test Loss : nan Test Accuracy : 8.50
# Epoch : 19500 Train Loss : nan Train Accuracy : 6.62 Test Loss : nan Test Accuracy : 11.00
# Epoch : 19600 Train Loss : nan Train Accuracy : 4.62 Test Loss : nan Test Accuracy : 7.50
# Epoch : 19700 Train Loss : nan Train Accuracy : 2.88 Test Loss : nan Test Accuracy : 5.50
# Epoch : 19800 Train Loss : nan Train Accuracy : 2.00 Test Loss : nan Test Accuracy : 4.00
# Epoch : 19900 Train Loss : nan Train Accuracy : 3.12 Test Loss : nan Test Accuracy : 10.00
# Epoch : 20000 Train Loss : nan Train Accuracy : 6.38 Test Loss : nan Test Accuracy : 9.00
# Epoch : 20100 Train Loss : nan Train Accuracy : 3.38 Test Loss : nan Test Accuracy : 7.00
# Epoch : 20200 Train Loss : nan Train Accuracy : 2.25 Test Loss : nan Test Accuracy : 4.00
# Epoch : 20300 Train Loss : nan Train Accuracy : 2.00 Test Loss : nan Test Accuracy : 6.00
# Epoch : 20400 Train Loss : nan Train Accuracy : 6.62 Test Loss : nan Test Accuracy : 11.00
# Epoch : 20500 Train Loss : nan Train Accuracy : 5.00 Test Loss : nan Test Accuracy : 8.00
# Epoch : 20600 Train Loss : nan Train Accuracy : 3.12 Test Loss : nan Test Accuracy : 5.50
# Epoch : 20700 Train Loss : nan Train Accuracy : 2.00 Test Loss : nan Test Accuracy : 4.00
# Epoch : 20800 Train Loss : nan Train Accuracy : 2.25 Test Loss : nan Test Accuracy : 9.50
# Epoch : 20900 Train Loss : nan Train Accuracy : 6.62 Test Loss : nan Test Accuracy : 9.50
# Epoch : 21000 Train Loss : nan Train Accuracy : 3.75 Test Loss : nan Test Accuracy : 7.00
# Epoch : 21100 Train Loss : nan Train Accuracy : 2.38 Test Loss : nan Test Accuracy : 4.50
# Epoch : 21200 Train Loss : nan Train Accuracy : 2.00 Test Loss : nan Test Accuracy : 5.00
# Epoch : 21300 Train Loss : nan Train Accuracy : 6.12 Test Loss : nan Test Accuracy : 10.50
# Epoch : 21400 Train Loss : nan Train Accuracy : 5.25 Test Loss : nan Test Accuracy : 8.00
# Epoch : 21500 Train Loss : nan Train Accuracy : 3.50 Test Loss : nan Test Accuracy : 6.00
# Epoch : 21600 Train Loss : nan Train Accuracy : 2.00 Test Loss : nan Test Accuracy : 3.50
# Epoch : 21700 Train Loss : nan Train Accuracy : 2.12 Test Loss : nan Test Accuracy : 9.00
# Epoch : 21800 Train Loss : nan Train Accuracy : 6.62 Test Loss : nan Test Accuracy : 10.50
# Epoch : 21900 Train Loss : nan Train Accuracy : 4.00 Test Loss : nan Test Accuracy : 7.50
# Epoch : 22000 Train Loss : nan Train Accuracy : 2.88 Test Loss : nan Test Accuracy : 5.50
# Epoch : 22100 Train Loss : nan Train Accuracy : 2.00 Test Loss : nan Test Accuracy : 5.00
# Epoch : 22200 Train Loss : nan Train Accuracy : 5.12 Test Loss : nan Test Accuracy : 10.50
# Epoch : 22300 Train Loss : nan Train Accuracy : 6.25 Test Loss : nan Test Accuracy : 8.50
# Epoch : 22400 Train Loss : nan Train Accuracy : 3.50 Test Loss : nan Test Accuracy : 6.50
# Epoch : 22500 Train Loss : nan Train Accuracy : 2.00 Test Loss : nan Test Accuracy : 3.50
# Epoch : 22600 Train Loss : nan Train Accuracy : 2.12 Test Loss : nan Test Accuracy : 9.00
# Epoch : 22700 Train Loss : nan Train Accuracy : 6.75 Test Loss : nan Test Accuracy : 11.00
# Epoch : 22800 Train Loss : nan Train Accuracy : 4.38 Test Loss : nan Test Accuracy : 7.50
# Epoch : 22900 Train Loss : nan Train Accuracy : 2.88 Test Loss : nan Test Accuracy : 5.50
# Epoch : 23000 Train Loss : nan Train Accuracy : 2.00 Test Loss : nan Test Accuracy : 4.50
# Epoch : 23100 Train Loss : nan Train Accuracy : 3.38 Test Loss : nan Test Accuracy : 10.50
# Epoch : 23200 Train Loss : nan Train Accuracy : 6.38 Test Loss : nan Test Accuracy : 9.00
# Epoch : 23300 Train Loss : nan Train Accuracy : 3.38 Test Loss : nan Test Accuracy : 7.00
# Epoch : 23400 Train Loss : nan Train Accuracy : 2.25 Test Loss : nan Test Accuracy : 4.00
# Epoch : 23500 Train Loss : nan Train Accuracy : 2.00 Test Loss : nan Test Accuracy : 6.50
# Epoch : 23600 Train Loss : nan Train Accuracy : 6.62 Test Loss : nan Test Accuracy : 11.50
# Epoch : 23700 Train Loss : nan Train Accuracy : 4.88 Test Loss : nan Test Accuracy : 8.00
# Epoch : 23800 Train Loss : nan Train Accuracy : 3.12 Test Loss : nan Test Accuracy : 5.50
# Epoch : 23900 Train Loss : nan Train Accuracy : 2.00 Test Loss : nan Test Accuracy : 4.00
# Epoch : 24000 Train Loss : nan Train Accuracy : 2.38 Test Loss : nan Test Accuracy : 9.50
# Epoch : 24100 Train Loss : nan Train Accuracy : 6.62 Test Loss : nan Test Accuracy : 9.50
# Epoch : 24200 Train Loss : nan Train Accuracy : 3.75 Test Loss : nan Test Accuracy : 7.00
# Epoch : 24300 Train Loss : nan Train Accuracy : 2.38 Test Loss : nan Test Accuracy : 4.50
# Epoch : 24400 Train Loss : nan Train Accuracy : 2.00 Test Loss : nan Test Accuracy : 5.00
# Epoch : 24500 Train Loss : nan Train Accuracy : 6.25 Test Loss : nan Test Accuracy : 10.50
# Epoch : 24600 Train Loss : nan Train Accuracy : 5.25 Test Loss : nan Test Accuracy : 8.00
# Epoch : 24700 Train Loss : nan Train Accuracy : 3.50 Test Loss : nan Test Accuracy : 6.00
# Epoch : 24800 Train Loss : nan Train Accuracy : 2.00 Test Loss : nan Test Accuracy : 3.50
# Epoch : 24900 Train Loss : nan Train Accuracy : 2.12 Test Loss : nan Test Accuracy : 9.50
# Epoch : 25000 Train Loss : nan Train Accuracy : 6.62 Test Loss : nan Test Accuracy : 10.00
# Epoch : 25100 Train Loss : nan Train Accuracy : 4.00 Test Loss : nan Test Accuracy : 7.00
# Epoch : 25200 Train Loss : nan Train Accuracy : 2.75 Test Loss : nan Test Accuracy : 5.50
# Epoch : 25300 Train Loss : nan Train Accuracy : 2.00 Test Loss : nan Test Accuracy : 5.00
# Epoch : 25400 Train Loss : nan Train Accuracy : 5.50 Test Loss : nan Test Accuracy : 10.50
# Epoch : 25500 Train Loss : nan Train Accuracy : 6.12 Test Loss : nan Test Accuracy : 8.50
# Epoch : 25600 Train Loss : nan Train Accuracy : 3.50 Test Loss : nan Test Accuracy : 6.50
# Epoch : 25700 Train Loss : nan Train Accuracy : 2.00 Test Loss : nan Test Accuracy : 3.50
# Epoch : 25800 Train Loss : nan Train Accuracy : 2.12 Test Loss : nan Test Accuracy : 9.00
# Epoch : 25900 Train Loss : nan Train Accuracy : 6.75 Test Loss : nan Test Accuracy : 11.00
# Epoch : 26000 Train Loss : nan Train Accuracy : 4.38 Test Loss : nan Test Accuracy : 7.50
# Epoch : 26100 Train Loss : nan Train Accuracy : 2.88 Test Loss : nan Test Accuracy : 5.50
# Epoch : 26200 Train Loss : nan Train Accuracy : 2.00 Test Loss : nan Test Accuracy : 4.50
# Epoch : 26300 Train Loss : nan Train Accuracy : 3.75 Test Loss : nan Test Accuracy : 10.50
# Epoch : 26400 Train Loss : nan Train Accuracy : 6.25 Test Loss : nan Test Accuracy : 9.00
# Epoch : 26500 Train Loss : nan Train Accuracy : 3.38 Test Loss : nan Test Accuracy : 7.00
# Epoch : 26600 Train Loss : nan Train Accuracy : 2.25 Test Loss : nan Test Accuracy : 4.00
# Epoch : 26700 Train Loss : nan Train Accuracy : 2.00 Test Loss : nan Test Accuracy : 6.50
# Epoch : 26800 Train Loss : nan Train Accuracy : 6.62 Test Loss : nan Test Accuracy : 11.50
# Epoch : 26900 Train Loss : nan Train Accuracy : 4.88 Test Loss : nan Test Accuracy : 8.00
# Epoch : 27000 Train Loss : nan Train Accuracy : 3.12 Test Loss : nan Test Accuracy : 5.50
# Epoch : 27100 Train Loss : nan Train Accuracy : 2.00 Test Loss : nan Test Accuracy : 4.00
# Epoch : 27200 Train Loss : nan Train Accuracy : 2.38 Test Loss : nan Test Accuracy : 9.50
# Epoch : 27300 Train Loss : nan Train Accuracy : 6.62 Test Loss : nan Test Accuracy : 9.50
# Epoch : 27400 Train Loss : nan Train Accuracy : 3.75 Test Loss : nan Test Accuracy : 7.00
# Epoch : 27500 Train Loss : nan Train Accuracy : 2.38 Test Loss : nan Test Accuracy : 4.50
# Epoch : 27600 Train Loss : nan Train Accuracy : 2.00 Test Loss : nan Test Accuracy : 5.50
# Epoch : 27700 Train Loss : nan Train Accuracy : 6.25 Test Loss : nan Test Accuracy : 10.50
# Epoch : 27800 Train Loss : nan Train Accuracy : 5.25 Test Loss : nan Test Accuracy : 8.00
# Epoch : 27900 Train Loss : nan Train Accuracy : 3.50 Test Loss : nan Test Accuracy : 5.50
# Epoch : 28000 Train Loss : nan Train Accuracy : 2.00 Test Loss : nan Test Accuracy : 3.50
# Epoch : 28100 Train Loss : nan Train Accuracy : 2.12 Test Loss : nan Test Accuracy : 9.50
# Epoch : 28200 Train Loss : nan Train Accuracy : 6.62 Test Loss : nan Test Accuracy : 10.00
# Epoch : 28300 Train Loss : nan Train Accuracy : 3.75 Test Loss : nan Test Accuracy : 7.00
# Epoch : 28400 Train Loss : nan Train Accuracy : 2.62 Test Loss : nan Test Accuracy : 5.00
# Epoch : 28500 Train Loss : nan Train Accuracy : 2.00 Test Loss : nan Test Accuracy : 5.00
# Epoch : 28600 Train Loss : nan Train Accuracy : 5.62 Test Loss : nan Test Accuracy : 10.50
# Epoch : 28700 Train Loss : nan Train Accuracy : 6.00 Test Loss : nan Test Accuracy : 8.50
# Epoch : 28800 Train Loss : nan Train Accuracy : 3.50 Test Loss : nan Test Accuracy : 6.50
# Epoch : 28900 Train Loss : nan Train Accuracy : 2.00 Test Loss : nan Test Accuracy : 3.50
# Epoch : 29000 Train Loss : nan Train Accuracy : 2.12 Test Loss : nan Test Accuracy : 9.00
# Epoch : 29100 Train Loss : nan Train Accuracy : 6.75 Test Loss : nan Test Accuracy : 11.00
# Epoch : 29200 Train Loss : nan Train Accuracy : 4.25 Test Loss : nan Test Accuracy : 7.50
# Epoch : 29300 Train Loss : nan Train Accuracy : 2.88 Test Loss : nan Test Accuracy : 5.50
# Epoch : 29400 Train Loss : nan Train Accuracy : 2.00 Test Loss : nan Test Accuracy : 4.50
# Epoch : 29500 Train Loss : nan Train Accuracy : 4.12 Test Loss : nan Test Accuracy : 10.50
# Epoch : 29600 Train Loss : nan Train Accuracy : 6.25 Test Loss : nan Test Accuracy : 9.00
# Epoch : 29700 Train Loss : nan Train Accuracy : 3.38 Test Loss : nan Test Accuracy : 7.00
# Epoch : 29800 Train Loss : nan Train Accuracy : 2.00 Test Loss : nan Test Accuracy : 4.00
# Epoch : 29900 Train Loss : nan Train Accuracy : 2.12 Test Loss : nan Test Accuracy : 7.00
# Epoch : 30000 Train Loss : nan Train Accuracy : 6.62 Test Loss : nan Test Accuracy : 11.50
# Epoch : 30100 Train Loss : nan Train Accuracy : 4.62 Test Loss : nan Test Accuracy : 8.00
# Epoch : 30200 Train Loss : nan Train Accuracy : 3.12 Test Loss : nan Test Accuracy : 5.50
# Epoch : 30300 Train Loss : nan Train Accuracy : 2.00 Test Loss : nan Test Accuracy : 4.00
# Epoch : 30400 Train Loss : nan Train Accuracy : 2.62 Test Loss : nan Test Accuracy : 10.00
# Epoch : 30500 Train Loss : nan Train Accuracy : 6.38 Test Loss : nan Test Accuracy : 9.00
# Epoch : 30600 Train Loss : nan Train Accuracy : 3.75 Test Loss : nan Test Accuracy : 7.00
# Epoch : 30700 Train Loss : nan Train Accuracy : 2.38 Test Loss : nan Test Accuracy : 4.50
# Epoch : 30800 Train Loss : nan Train Accuracy : 2.00 Test Loss : nan Test Accuracy : 6.00
# Epoch : 30900 Train Loss : nan Train Accuracy : 6.38 Test Loss : nan Test Accuracy : 10.50
# Epoch : 31000 Train Loss : nan Train Accuracy : 5.25 Test Loss : nan Test Accuracy : 8.00
# Epoch : 31100 Train Loss : nan Train Accuracy : 3.38 Test Loss : nan Test Accuracy : 5.50
# Epoch : 31200 Train Loss : nan Train Accuracy : 2.00 Test Loss : nan Test Accuracy : 3.50
# Epoch : 31300 Train Loss : nan Train Accuracy : 2.12 Test Loss : nan Test Accuracy : 9.50
# Epoch : 31400 Train Loss : nan Train Accuracy : 6.62 Test Loss : nan Test Accuracy : 10.00
# Epoch : 31500 Train Loss : nan Train Accuracy : 3.75 Test Loss : nan Test Accuracy : 7.00
# Epoch : 31600 Train Loss : nan Train Accuracy : 2.62 Test Loss : nan Test Accuracy : 4.50
# Epoch : 31700 Train Loss : nan Train Accuracy : 2.00 Test Loss : nan Test Accuracy : 5.00
# Epoch : 31800 Train Loss : nan Train Accuracy : 5.62 Test Loss : nan Test Accuracy : 10.50
# Epoch : 31900 Train Loss : nan Train Accuracy : 6.00 Test Loss : nan Test Accuracy : 8.50
# Epoch : 32000 Train Loss : nan Train Accuracy : 3.50 Test Loss : nan Test Accuracy : 6.50
# Epoch : 32100 Train Loss : nan Train Accuracy : 2.00 Test Loss : nan Test Accuracy : 3.50
# Epoch : 32200 Train Loss : nan Train Accuracy : 2.12 Test Loss : nan Test Accuracy : 9.00
# Epoch : 32300 Train Loss : nan Train Accuracy : 6.62 Test Loss : nan Test Accuracy : 11.00
# Epoch : 32400 Train Loss : nan Train Accuracy : 4.12 Test Loss : nan Test Accuracy : 7.50
# Epoch : 32500 Train Loss : nan Train Accuracy : 2.88 Test Loss : nan Test Accuracy : 5.50
# Epoch : 32600 Train Loss : nan Train Accuracy : 2.00 Test Loss : nan Test Accuracy : 4.50
# Epoch : 32700 Train Loss : nan Train Accuracy : 4.38 Test Loss : nan Test Accuracy : 10.50
# Epoch : 32800 Train Loss : nan Train Accuracy : 6.12 Test Loss : nan Test Accuracy : 8.50
# Epoch : 32900 Train Loss : nan Train Accuracy : 3.38 Test Loss : nan Test Accuracy : 7.00
# Epoch : 33000 Train Loss : nan Train Accuracy : 2.00 Test Loss : nan Test Accuracy : 4.00
# Epoch : 33100 Train Loss : nan Train Accuracy : 2.12 Test Loss : nan Test Accuracy : 8.00
# Epoch : 33200 Train Loss : nan Train Accuracy : 6.62 Test Loss : nan Test Accuracy : 11.00
# Epoch : 33300 Train Loss : nan Train Accuracy : 4.62 Test Loss : nan Test Accuracy : 8.00
# Epoch : 33400 Train Loss : nan Train Accuracy : 3.12 Test Loss : nan Test Accuracy : 5.50
# Epoch : 33500 Train Loss : nan Train Accuracy : 2.00 Test Loss : nan Test Accuracy : 4.00
# Epoch : 33600 Train Loss : nan Train Accuracy : 2.88 Test Loss : nan Test Accuracy : 10.00
# Epoch : 33700 Train Loss : nan Train Accuracy : 6.38 Test Loss : nan Test Accuracy : 9.00
# Epoch : 33800 Train Loss : nan Train Accuracy : 3.50 Test Loss : nan Test Accuracy : 7.00
# Epoch : 33900 Train Loss : nan Train Accuracy : 2.25 Test Loss : nan Test Accuracy : 4.00
# Epoch : 34000 Train Loss : nan Train Accuracy : 2.00 Test Loss : nan Test Accuracy : 6.00
# Epoch : 34100 Train Loss : nan Train Accuracy : 6.38 Test Loss : nan Test Accuracy : 10.50
# Epoch : 34200 Train Loss : nan Train Accuracy : 5.25 Test Loss : nan Test Accuracy : 8.00
# Epoch : 34300 Train Loss : nan Train Accuracy : 3.12 Test Loss : nan Test Accuracy : 5.50
# Epoch : 34400 Train Loss : nan Train Accuracy : 2.00 Test Loss : nan Test Accuracy : 3.50
# Epoch : 34500 Train Loss : nan Train Accuracy : 2.25 Test Loss : nan Test Accuracy : 9.50
# Epoch : 34600 Train Loss : nan Train Accuracy : 6.62 Test Loss : nan Test Accuracy : 10.00
# Epoch : 34700 Train Loss : nan Train Accuracy : 3.75 Test Loss : nan Test Accuracy : 7.00
# Epoch : 34800 Train Loss : nan Train Accuracy : 2.38 Test Loss : nan Test Accuracy : 4.50
# Epoch : 34900 Train Loss : nan Train Accuracy : 2.00 Test Loss : nan Test Accuracy : 5.00
# Epoch : 35000 Train Loss : nan Train Accuracy : 5.88 Test Loss : nan Test Accuracy : 10.50
# Epoch : 35100 Train Loss : nan Train Accuracy : 5.75 Test Loss : nan Test Accuracy : 8.00
# Epoch : 35200 Train Loss : nan Train Accuracy : 3.50 Test Loss : nan Test Accuracy : 6.00
# Epoch : 35300 Train Loss : nan Train Accuracy : 2.00 Test Loss : nan Test Accuracy : 3.50
# Epoch : 35400 Train Loss : nan Train Accuracy : 2.12 Test Loss : nan Test Accuracy : 9.00
# Epoch : 35500 Train Loss : nan Train Accuracy : 6.62 Test Loss : nan Test Accuracy : 11.00
# Epoch : 35600 Train Loss : nan Train Accuracy : 4.00 Test Loss : nan Test Accuracy : 7.50
# Epoch : 35700 Train Loss : nan Train Accuracy : 2.88 Test Loss : nan Test Accuracy : 5.50
# Epoch : 35800 Train Loss : nan Train Accuracy : 2.00 Test Loss : nan Test Accuracy : 5.00
# Epoch : 35900 Train Loss : nan Train Accuracy : 5.12 Test Loss : nan Test Accuracy : 10.50
# Epoch : 36000 Train Loss : nan Train Accuracy : 6.12 Test Loss : nan Test Accuracy : 8.50
# Epoch : 36100 Train Loss : nan Train Accuracy : 3.50 Test Loss : nan Test Accuracy : 7.00
# Epoch : 36200 Train Loss : nan Train Accuracy : 2.00 Test Loss : nan Test Accuracy : 4.00
# Epoch : 36300 Train Loss : nan Train Accuracy : 2.12 Test Loss : nan Test Accuracy : 8.00
# Epoch : 36400 Train Loss : nan Train Accuracy : 6.62 Test Loss : nan Test Accuracy : 11.00
# Epoch : 36500 Train Loss : nan Train Accuracy : 4.62 Test Loss : nan Test Accuracy : 7.50
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[70], line 23
#      21 w_T.append(w)
#      22 # Test model
# ---> 23 accTe , lossTe , w = gradient_descent(y_test , np.c_[np.ones(x_test_norm.shape[0]) , x_test_norm] , w ,gamma , Train = False)
#      24 acc_Te.append(accTe)
#      25 loss_Te.append(lossTe)
#
# Cell In[65], line 8, in gradient_descent(y, x, w, gamma, Train)
#       6     gradient = x.T.dot(y_hat - y)
#       7     w = w - (gamma * gradient)
# ----> 8 acc = float(np.equal(y_hat , y).sum() / len(y))
#       9 return acc * 100 , loss , w
#
# File ~/anaconda3/lib/python3.9/site-packages/numpy/core/_methods.py:48, in _sum(a, axis, dtype, out, keepdims, initial, where)
#      46 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      47          initial=_NoValue, where=True):
# ---> 48     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#
# KeyboardInterrupt:

# %%
plt.plot(epochs , loss_T , label="loss_Train")
plt.plot(epochs , loss_Te , label="loss_Test")
plt.legend()
plt.figure()

plt.plot(epochs , acc_T , label="acc_Train")
plt.plot(epochs , acc_Te , label="acc_Test")
plt.legend()
